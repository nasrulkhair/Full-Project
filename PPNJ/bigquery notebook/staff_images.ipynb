# %%
import pandas as pd

staff_name = ['Izzah', 'Wadah', 'Nasir','Nasrul', 'Nuha', 'Alissa', 'Khair', 'Intan', 'Amira']
staff_image = [
    'https://media.istockphoto.com/id/1159212661/photo/portrait-of-successful-young-asian-businesswoman%C3%A2%C2%A0at-office-colleagues-in-background.jpg?s=2048x2048&w=is&k=20&c=DU7fdeybS5N8x5RazQI2mm0i0nb-gDVXuWCeKYG7cRo=',
    'https://media.istockphoto.com/id/817218478/photo/portrait-happy-business-woman-in-the-office.jpg?s=2048x2048&w=is&k=20&c=GBzoQUmuZkovTX6zGZLHz6Erfco52OuvrXpnSaEfwCI=',
    'https://media.istockphoto.com/id/2196264474/photo/headshot-of-friendly-businessman.jpg?s=2048x2048&w=is&k=20&c=yWVGkMZqy-61y_jnFA-jznz8JUxHr9e8g1chdClul7E=',
    'https://media.istockphoto.com/id/649730298/photo/business-smile.jpg?s=2048x2048&w=is&k=20&c=UX2CViy69CF8MnQN-CfUcxD9xwmCxmgoagudeDTfe6w=',
    'https://media.istockphoto.com/id/1462967932/photo/asian-business-woman-working-at-home-office-and-analyze-financial-report-document-accounting.jpg?s=2048x2048&w=is&k=20&c=v088fpKH3Q1XeXMq26SFtKkEHxWMD7yoUrNEPZDo0t0=',
    'https://media.istockphoto.com/id/1412646179/photo/portrait-of-a-business-woman-standing-with-her-arms-crossed.jpg?s=612x612&w=0&k=20&c=fwJ9o_hjtPg9NLNj5VuFsUJ_xGoBgs_a5x5bTj6x6tY=',
    'https://media.istockphoto.com/id/991876120/photo/success-has-always-been-destined-for-me.jpg?s=612x612&w=0&k=20&c=mbIVpgTlWj46Gx3A6FnOMmnuuJ9VCLqlKjCo8GEtKvc=',
    'https://media.istockphoto.com/id/1521092930/photo/a-confident-asian-businesswoman-stands-with-the-meeting-room-with-her-arms-crossed.jpg?s=612x612&w=0&k=20&c=i6j5P66Zt5dXWXLFqdVbKoimdbbtpH-Pgcl_SrbyCWk=',
    'https://media.istockphoto.com/id/1421161311/photo/businesswoman-manager-smiling-looking-at-the-camera-with-crossed-arms.jpg?s=612x612&w=0&k=20&c=9Ezv93iXRVegByP2LKoQNZUaslbbLBn7ANED3Mb-1As='
]

staff_image = pd.DataFrame({
    'staff_name': staff_name,
    'image_url': staff_image
})

staff_image.head()
# Out:
#   staff_name                                          image_url
# 0      Izzah  https://media.istockphoto.com/id/1159212661/ph...
# 1      Wadah  https://media.istockphoto.com/id/817218478/pho...
# 2      Nasir  https://media.istockphoto.com/id/2196264474/ph...
# 3     Nasrul  https://media.istockphoto.com/id/649730298/pho...
# 4       Nuha  https://media.istockphoto.com/id/1462967932/ph...

# %%
# saving to gcs
staff_image.to_csv(
    'gs://ppnj_data/files/staff_images.csv',
    index=False,
    storage_options={"token": "cloud"}
)
