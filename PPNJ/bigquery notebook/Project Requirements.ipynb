# %% [markdown]
# ## Project Requirements

# %% [markdown]
# | Step                                | Done?                     | Notes                                              |
# | ----------------------------------- | ------------------------- | -------------------------------------------------- |
# | 0. BRD / Business Requirements      |   ✅                       | Let’s generate one together soon                   |
# | 1. Data Creation                    | ✅                         | Complete                                           |
# | 2. Data Transformation              | ✅                         | Complete                                           |
# | 3. Data Validation / QA             | ✅                         | Done with QA logic                                 |
# | 4. Upload to GCS                    | ✅                         | Done                                               |
# | 5. Query Analysis                   | ✅                         | You’ve run many solid queries                      |
# | 6. Data Dictionary / Docs           | ✅                         | Confirmed                                          |
# | 7. EDA                              | ✅                         | Explored with charts/stats                         |
# | 8. Power BI Dashboard               | ✅                         |  built                                      |
# | 9. KPI Dashboard / Summary Page     | ✅  | You’ve done this in code — needs Power BI design   |
# | 10. Insight Log / Journal           | ❌                         | This is where you summarize findings + add meaning |
# | 11. Report Writing (Word/PDF)       | ❌                         | Needed for portfolio delivery                      |
# | 12. Presentation Slide (PPT/Prezi)  | ❌                         | Needed — with story + visuals                      |
# | 13. Business Recommendations Slide  | ❌                         | Based on insights + what-if outcomes               |
# | 14. What-If / Scenario Modelling    | ✅                         | Done beautifully for 3 key ideas                   |
# | 15. Hypothesis Testing              | ✅ | Can skip if short on time                          |
# | 16. Executive Summary Slide         | ✅ (content done)          | Slide design remaining                             |
# | 17. GitHub Repository               | ✅                         | Highly recommended for public demo                 |
# | 18. DAG / Automation Plan           | ❌ (optional)              | Add if you want to wow technical recruiters        |
# | 19. User Stories / Use Case Mapping | ❌                         | Bonus BA skill — optional                          |
